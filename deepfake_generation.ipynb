# %%
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# Out:
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 299, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 299 (delta 2), reused 2 (delta 0), pack-reused 293
# Receiving objects: 100% (299/299), 72.15 MiB | 37.69 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# Checking out files: 100% (47/47), done.

# %%
# !cd first-order-model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell')

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

source_image = imageio.imread("/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/Akash.jpg")
reader = imageio.get_reader('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/04.mp4')

#Image resizing
source_image = resize(source_image, (256, 256))[..., :3]

fps = reader.get_meta_data()['fps']
driving_video = []

try:
    for im in reader:
        driving_video.append(im)
except RuntimeError:
    pass
reader.close()

driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# !ls "/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell"
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# 00.mp4	09.png		 cartoon-03.png   got-02.png	 statue-02.png
# 01.png	10-backward.mp4  cartoon-04.jpg   got-03.png	 statue-03.png
# 02.png	10.mp4		 cartoons-01.png  got-04.png	 statue-04.png
# 03.png	11.png		 doll-01.png	  got-05.png	 vox-adv-cpk.pth.tar
# 04.mp4	12.png		 doll-02.png	  got-06.png	 vox-cpk.pth.tar
# 05.png	Akash.jpg	 doll-03.png	  got-07.png
# 06.png	Akash_side.jpg	 doll-05.png	  got-08.png
# 07.mkv	ankith.jpg	 doll-08.png	  got-09.png
# 08.mp4	cartoon-02.png	 got-01.png	  statue-01.png

# %%
pip install ffmpy &> /dev/null

# %%
# !cd "/content/first-order-model/"

# %%
os.chdir('/content/first-order-model/')

# %%
# !ls
# Out:
# animate.py	 demo.ipynb	    logger.py	       requirements.txt
# augmentation.py  demo.py	    modules	       run.py
# config		 Dockerfile	    old_demo.ipynb     sup-mat
# crop-video.py	 frames_dataset.py  README.md	       sync_batchnorm
# data		 LICENSE.md	    reconstruction.py  train.py

# %%
from demo import load_checkpoints, make_animation

# %%
from demo import load_checkpoints

generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml',checkpoint_path='/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/vox-cpk.pth.tar')

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#saving the resulting video
imageio.mimsave('../generated.mp4', [img_as_ubyte(frame) for frame in predictions], fps=fps)
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 211/211 [00:08<00:00, 25.16it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=False, adapt_movement_scale=True)
HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 211/211 [00:08<00:00, 25.46it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
ffmpeg -i /content/gdrive/MyDrive/first-order-motion-model/10.mp4 -ss 00:00:01.50 -t 00:00:12 -filter:v "crop=600:600:760:50" -async 1 dicapi.mp4

# %%
pip install ffmpeg
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp37-none-any.whl size=6084 sha256=4671d0dccc1381b2ebd159488b92cf733321fc5f3d6e508cec517a7ebb458b4d
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# Successfully built ffmpeg
# ...

# %%
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell')
# !ls
# Out:
# 00.mp4	09.png		 cartoon-03.png   got-02.png	 statue-02.png
# 01.png	10-backward.mp4  cartoon-04.jpg   got-03.png	 statue-03.png
# 02.png	10.mp4		 cartoons-01.png  got-04.png	 statue-04.png
# 03.png	11.png		 doll-01.png	  got-05.png	 vox-adv-cpk.pth.tar
# 04.mp4	12.png		 doll-02.png	  got-06.png	 vox-cpk.pth.tar
# 05.png	Akash.jpg	 doll-03.png	  got-07.png
# 06.png	Akash_side.jpg	 doll-05.png	  got-08.png
# 07.mkv	ankith.jpg	 doll-08.png	  got-09.png
# 08.mp4	cartoon-02.png	 got-01.png	  statue-01.png

# %%
vid07= '/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/07.mkv'
vid07
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/07.mkv'

# %%
# !ffmpeg -i /content/gdrive/MyDrive/vid07.mkv -ss 00:08:57.50 -t 00:00:08 -filter:v "crop=600:600:760:50" -async 1 hinton.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
source_image = imageio.imread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/05.png')
driving_video = imageio.mimread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/hinton.mp4', memtest=False)

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 240/240 [00:09<00:00, 26.34it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
source_image = imageio.imread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/Akash_side.jpg')
driving_video = imageio.mimread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/hinton.mp4', memtest=False)

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector,relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 240/240 [00:09<00:00, 24.47it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
source_image = imageio.imread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/06.png')
driving_video = imageio.mimread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/00.mp4', memtest=False)

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 265/265 [00:13<00:00, 19.38it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
driving_video = imageio.mimread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/07.mkv', memtest=False)
# !ffmpeg -i driving_video -ss 00:08:57.50 -t 00:00:08 -filter:v "crop=600:600:760:50" -async 1 hinton.mp4

source_image = imageio.imread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/05.png')
driv_video = imageio.mimread('/content/gdrive/MyDrive/Colab Notebooks/first-order-motion-modell/hinton.mp4', memtest=False)

source_image = resize(source_image, (256, 256))[..., :3]
driv_video = [resize(frame, (256, 256))[..., :3] for frame in driv_video]

predictions = make_animation(source_image, driv_video, generator, kp_detector, relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())

# %%
 from google.colab.patches import cv2_imshow

# %%
"""from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename """

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  display(Image(filename))
except Exception as err:
  print(str(err))

# %%
import cv2
import dlib
import os
import numpy as np
from skimage import io

#path = os.path.dirname(__file__)
os.chdir('/content/gdrive/MyDrive/first-order-motion-model')

cap = cv2.VideoCapture(1, cv2.CAP_DSHOW)
face_img = cap.read()[0]
fourcc = cv2.VideoWriter_fourcc(*'XVID') 
video = cv2.VideoWriter('main.mp4', fourcc, 20.0, (640, 480)) 
detector = dlib.get_frontal_face_detector()

#trial
def imcrop(img, bbox): 
    x1,y1,x2,y2 = bbox
    if x1 < 0 or y1 < 0 or x2 > img.shape[1] or y2 > img.shape[0]:
        img, x1, x2, y1, y2 = pad_img_to_fit_bbox(img, x1, x2, y1, y2)
    return img[y1:y2, x1:x2, :]

def pad_img_to_fit_bbox(img, x1, x2, y1, y2):
    img = np.pad(img, ((np.abs(np.minimum(0, y1)), np.maximum(y2 - img.shape[0], 0)),
               (np.abs(np.minimum(0, x1)), np.maximum(x2 - img.shape[1], 0)), (0,0)), mode='constant')
    y1 += np.abs(np.minimum(0, y1))
    y2 += np.abs(np.minimum(0, y1))
    x1 += np.abs(np.minimum(0, x1))
    x2 += np.abs(np.minimum(0, x1))
    return img, x1, x2, y1, y2

while True:
    ret, frame = cap.read()
    if ret == False:
      break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)

    for face in faces:
        x1 = face.left()
        y1 = face.top()
        x2 = face.right()
        y2 = face.bottom()
        bbox = (x1, y1, x2, y2)
        frame = imcrop(frame, bbox)
        print('Face cap')

    video.write(frame)

    cv2.imshow('Frame', frame)

    key = cv2.waitKey(20)
    if key == 27:
        break

cap.release() 
video.release() 
cv2.destroyAllWindows()
